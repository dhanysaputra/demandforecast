# %% [markdown]
# # 04 — Croston + Hybrid Forecasting

# %%
import pandas as pd
from src.forecasting.croston import croston_sba
from src.forecasting.hybrid_forecast import hybrid_forecast

inv_df = pd.read_pickle("../data/inv_df.pkl")
demand_ts = inv_df['true_demand_est']

fitted, croston_future = croston_sba(demand_ts, h=6)

hybrid_future, debug = hybrid_forecast(demand_ts, steps=6)
hybrid_future, debug
